# %%
import pandas as pd

# %%
df=pd.read_csv("/kaggle/input/facebook/dataset_Facebook - dataset_Facebook (1).csv")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (500, 19)

# %%
df.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
df.tail()
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 495             85093  Photo         3           1             7          2
# 496             81370  Photo         2           1             5          8
# 497             81370  Photo         1           1             5          2
# 498             81370  Photo         3           1             4         11
# ...

# %%
df.head(10)
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
# 5            139441  Status         2          12             1          9
# 6            139441   Photo         3          12             1          3
# 7            139441   Photo         3          12             7          9
# 8            139441  Status         2          12             7          3
# 9            139441   Photo         3          12             6         10
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# ...

# %%
df.iloc[2:10,:]
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
# 5            139441  Status         2          12             1          9
# 6            139441   Photo         3          12             1          3
# 7            139441   Photo         3          12             7          9
# 8            139441  Status         2          12             7          3
# 9            139441   Photo         3          12             6         10
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
# ...

# %%
df.iloc[:,16]
# Out:
# 0        79.0
# 1       130.0
# 2        66.0
# 3      1572.0
# 4       325.0
#         ...
# 495      53.0
# 496      53.0
# 497      93.0
# 498      91.0
# 499      91.0
# Name: like, Length: 500, dtype: float64

# %%
df.iloc[[1,4,7,18,19,40],[1,3,5,8,9]]
# Out:
#       Type  Post Month  Post Hour  Lifetime Post Total Impressions  \
# 1   Status          12         10                            19057
# 4    Photo          12          3                            13594
# 7    Photo          12          9                            24137
# 18  Status          12          3                             7509
# 19   Photo          12         11                             2825
# 40  Status          12         11                            24198
#
#     Lifetime Engaged Users
# 1                     1457
# 4                      671
# 7                      537
# 18                     130
# 19                     121
# 40                    2055

# %%
df.loc[1:20,'Type']
# Out:
# 1     Status
# 2      Photo
# 3      Photo
# 4      Photo
# 5     Status
# 6      Photo
# 7      Photo
# 8     Status
# 9      Photo
# 10    Status
# 11     Photo
# 12     Photo
# 13     Photo
# 14     Photo
# 15    Status
# 16     Photo
# 17     Photo
# 18    Status
# 19     Photo
# 20     Photo
# Name: Type, dtype: object

# %%
df.loc[:,['Type','Post Month']]
# Out:
#        Type  Post Month
# 0     Photo          12
# 1    Status          12
# 2     Photo          12
# 3     Photo          12
# 4     Photo          12
# ..      ...         ...
# 495   Photo           1
# 496   Photo           1
# 497   Photo           1
# 498   Photo           1
# 499   Photo           1
#
# [500 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['Page total likes', 'Type', 'Category', 'Post Month', 'Post Weekday',
#        'Post Hour', 'Paid', 'Lifetime Post Total Reach',
#        'Lifetime Post Total Impressions', 'Lifetime Engaged Users',
#        'Lifetime Post Consumers', 'Lifetime Post Consumptions',
#        'Lifetime Post Impressions by people who have liked your Page',
#        'Lifetime Post reach by people who like your Page',
#        'Lifetime People who have liked your Page and engaged with your post',
#        'comment', 'like', 'share', 'Total Interactions'],
#       dtype='object')

# %%
x=df[['like','Lifetime Post Total Impressions', 'Lifetime Engaged Users',
       'Lifetime Post Consumers', 'Lifetime Post Consumptions',
       'Lifetime Post Impressions by people who have liked your Page']]

# %%
print(x)
# Out:
#        like  Lifetime Post Total Impressions  Lifetime Engaged Users  \
# 0      79.0                             5091                     178
# 1     130.0                            19057                    1457
# 2      66.0                             4373                     177
# 3    1572.0                            87991                    2211
# 4     325.0                            13594                     671
# ..      ...                              ...                     ...
# 495    53.0                             7536                     733
# 496    53.0                             6229                     537
# 497    93.0                             7216                     625
# 498    91.0                             7564                     626
# 499    91.0                             7292                     564
#
#      Lifetime Post Consumers  Lifetime Post Consumptions  \
# 0                        109                         159
# ...

# %%
x.shape
# Out:
# (500, 6)

# %%
z=x[x['like']>100]
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/core/computation/expressions.py:73: RuntimeWarning: invalid value encountered in greater
#   return op(a, b)

# %%
z
# Out:
#        like  Lifetime Post Total Impressions  Lifetime Engaged Users  \
# 1     130.0                            19057                    1457
# 3    1572.0                            87991                    2211
# 4     325.0                            13594                     671
# 5     152.0                            20849                    1191
# 6     249.0                            19479                     481
# ..      ...                              ...                     ...
# 488   277.0                            17442                    1407
# 491   105.0                            10228                     956
# 492   128.0                             5808                     753
# 493   185.0                            13960                    1179
# 494   125.0                             9218                     810
#
#      Lifetime Post Consumers  Lifetime Post Consumptions  \
# 1                       1361                        1674
# ...

# %%
z.shape
# Out:
# (252, 6)

# %%
z=x[(x['like']>100)&(x['Lifetime Post Total Impressions']>4000)]
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/core/computation/expressions.py:73: RuntimeWarning: invalid value encountered in greater
#   return op(a, b)

# %%
z
# Out:
#        like  Lifetime Post Total Impressions  Lifetime Engaged Users  \
# 1     130.0                            19057                    1457
# 3    1572.0                            87991                    2211
# 4     325.0                            13594                     671
# 5     152.0                            20849                    1191
# 6     249.0                            19479                     481
# ..      ...                              ...                     ...
# 488   277.0                            17442                    1407
# 491   105.0                            10228                     956
# 492   128.0                             5808                     753
# 493   185.0                            13960                    1179
# 494   125.0                             9218                     810
#
#      Lifetime Post Consumers  Lifetime Post Consumptions  \
# 1                       1361                        1674
# ...

# %%
df.dtypes['like']
# Out:
# dtype('float64')

# %%
z.drop(4,axis=0,inplace=True)
# Out:
# /tmp/ipykernel_31/1117949711.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   z.drop(4,axis=0,inplace=True)

# %%
z
# Out:
#        like  Lifetime Post Total Impressions  Lifetime Engaged Users  \
# 1     130.0                            19057                    1457
# 3    1572.0                            87991                    2211
# 5     152.0                            20849                    1191
# 6     249.0                            19479                     481
# 7     325.0                            24137                     537
# ..      ...                              ...                     ...
# 488   277.0                            17442                    1407
# 491   105.0                            10228                     956
# 492   128.0                             5808                     753
# 493   185.0                            13960                    1179
# 494   125.0                             9218                     810
#
#      Lifetime Post Consumers  Lifetime Post Consumptions  \
# 1                       1361                        1674
# ...

# %%
z.to_csv('output.csv',index=False)

# %%
z.drop([6,7])
# Out:
#        like  Lifetime Post Total Impressions  Lifetime Engaged Users  \
# 1     130.0                            19057                    1457
# 3    1572.0                            87991                    2211
# 5     152.0                            20849                    1191
# 8     161.0                            22538                    1530
# 9     113.0                             8668                     280
# ..      ...                              ...                     ...
# 488   277.0                            17442                    1407
# 491   105.0                            10228                     956
# 492   128.0                             5808                     753
# 493   185.0                            13960                    1179
# 494   125.0                             9218                     810
#
#      Lifetime Post Consumers  Lifetime Post Consumptions  \
# 1                       1361                        1674
# ...

# %%
z
# Out:
#        like  Lifetime Post Total Impressions  Lifetime Engaged Users  \
# 1     130.0                            19057                    1457
# 3    1572.0                            87991                    2211
# 5     152.0                            20849                    1191
# 6     249.0                            19479                     481
# 7     325.0                            24137                     537
# ..      ...                              ...                     ...
# 488   277.0                            17442                    1407
# 491   105.0                            10228                     956
# 492   128.0                             5808                     753
# 493   185.0                            13960                    1179
# 494   125.0                             9218                     810
#
#      Lifetime Post Consumers  Lifetime Post Consumptions  \
# 1                       1361                        1674
# ...

# %%
df.drop('like',axis=1)
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# ...

# %%
df['Type']
# Out:
# 0       Photo
# 1      Status
# 2       Photo
# 3       Photo
# 4       Photo
#         ...
# 495     Photo
# 496     Photo
# 497     Photo
# 498     Photo
# 499     Photo
# Name: Type, Length: 500, dtype: object

# %%
df_subset_1 = df[['like','share']]
df_subset_1
# Out:
#        like  share
# 0      79.0   17.0
# 1     130.0   29.0
# 2      66.0   14.0
# 3    1572.0  147.0
# 4     325.0   49.0
# ..      ...    ...
# 495    53.0   26.0
# 496    53.0   22.0
# 497    93.0   18.0
# 498    91.0   38.0
# 499    91.0   28.0
#
# [500 rows x 2 columns]

# %%
df_subset_2 = df[['comment','Type']]
df_subset_2
# Out:
#      comment    Type
# 0          4   Photo
# 1          5  Status
# 2          0   Photo
# 3         58   Photo
# 4         19   Photo
# ..       ...     ...
# 495        5   Photo
# 496        0   Photo
# 497        4   Photo
# 498        7   Photo
# 499        0   Photo
#
# [500 rows x 2 columns]

# %%
merged_data  = pd.merge(df_subset_2, df_subset_1, left_on='comment', right_on= 'like')
merged_data
# Out:
#       comment    Type  like  share
# 0           4   Photo   4.0    2.0
# 1           4   Photo   4.0    1.0
# 2           4   Photo   4.0    0.0
# 3           4   Photo   4.0    1.0
# 4           5  Status   5.0    2.0
# ...       ...     ...   ...    ...
# 1462        0   Photo   0.0    0.0
# 1463        0   Photo   0.0    0.0
# 1464        0   Photo   0.0    0.0
# 1465        0   Photo   0.0    0.0
# 1466        0   Photo   0.0    0.0
#
# [1467 rows x 4 columns]

# %%
merged_data.sort_values(by=['like'],ascending=False)
# Out:
#       comment   Type   like  share
# 1351      146  Photo  146.0    9.0
# 1352      146  Photo  146.0   15.0
# 549       144  Photo  144.0   10.0
# 550       144  Photo  144.0   29.0
# 711        64  Photo   64.0   19.0
# ...       ...    ...    ...    ...
# 891         0  Photo    0.0    0.0
# 892         0  Photo    0.0    0.0
# 895         0  Photo    0.0    0.0
# 896         0  Photo    0.0    0.0
# 1466        0  Photo    0.0    0.0
#
# [1467 rows x 4 columns]

# %%
merged_data.shape
# Out:
# (1467, 4)

# %%
y=merged_data.T

# %%
y.shape
# Out:
# (4, 1467)

# %%
df.Type.unique()
# Out:
# array(['Photo', 'Status', 'Link', 'Video'], dtype=object)

# %%
pd.melt(df, id_vars =['Type'], value_vars =['comment'])
# Out:
#        Type variable  value
# 0     Photo  comment      4
# 1    Status  comment      5
# 2     Photo  comment      0
# 3     Photo  comment     58
# 4     Photo  comment     19
# ..      ...      ...    ...
# 495   Photo  comment      5
# 496   Photo  comment      0
# 497   Photo  comment      4
# 498   Photo  comment      7
# 499   Photo  comment      0
#
# [500 rows x 3 columns]
