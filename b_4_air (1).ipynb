# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/AirQuality_visualization - AirQuality_visualization (1).csv')

# %%
df
# Out:
#             Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  \
# 0     10/03/2004  18.00.00    2,6         1360       150     11,9
# 1     10/03/2004  19.00.00      2         1292       112      9,4
# 2     10/03/2004  20.00.00    2,2         1402        88      9,0
# 3     10/03/2004  21.00.00    2,2         1376        80      9,2
# 4     10/03/2004  22.00.00    1,6         1272        51      6,5
# ...          ...       ...    ...          ...       ...      ...
# 9352  04/04/2005  10.00.00    3,1         1314      -200     13,5
# 9353  04/04/2005  11.00.00    2,4         1163      -200     11,4
# 9354  04/04/2005  12.00.00    2,4         1142      -200     12,4
# 9355  04/04/2005  13.00.00    2,1         1003      -200      9,5
# 9356  04/04/2005  14.00.00    2,2         1071      -200     11,9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0              1046      166          1056      113          1692
# 1               955      103          1174       92          1559
# 2               939      131          1140      114          1555
# 3               948      172          1092      122          1584
# 4               836      131          1205      116          1490
# ...             ...      ...           ...      ...           ...
# 9352           1101      472           539      190          1374
# 9353           1027      353           604      179          1264
# 9354           1063      293           603      175          1241
# 9355            961      235           702      156          1041
# 9356           1047      265           654      168          1129
#
#       PT08.S5(O3)     T    RH     AH
# 0            1268  13,6  48,9  7,578
# 1             972  13,3  47,7  7,255
# 2            1074  11,9  54,0  7,502
# 3            1203  11,0  60,0  7,867
# 4            1110  11,2  59,6  7,888
# ...           ...   ...   ...    ...
# 9352         1729  21,9  29,3  7,568
# 9353         1269  24,3  23,7  7,119
# 9354         1092  26,9  18,3  6,406
# 9355          770  28,3  13,5  5,139
# 9356          816  28,5  13,1  5,028
#
# [9357 rows x 15 columns]

# %%
df = df.rename(columns={'T': 'Temperature'})
df = df.rename(columns={'RH': 'Relative Humidity'})
df = df.rename(columns={'AH': 'Absolute Humidity'})
df
# Out:
#             Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  \
# 0     10/03/2004  18.00.00    2,6         1360       150     11,9
# 1     10/03/2004  19.00.00      2         1292       112      9,4
# 2     10/03/2004  20.00.00    2,2         1402        88      9,0
# 3     10/03/2004  21.00.00    2,2         1376        80      9,2
# 4     10/03/2004  22.00.00    1,6         1272        51      6,5
# ...          ...       ...    ...          ...       ...      ...
# 9352  04/04/2005  10.00.00    3,1         1314      -200     13,5
# 9353  04/04/2005  11.00.00    2,4         1163      -200     11,4
# 9354  04/04/2005  12.00.00    2,4         1142      -200     12,4
# 9355  04/04/2005  13.00.00    2,1         1003      -200      9,5
# 9356  04/04/2005  14.00.00    2,2         1071      -200     11,9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0              1046      166          1056      113          1692
# 1               955      103          1174       92          1559
# 2               939      131          1140      114          1555
# 3               948      172          1092      122          1584
# 4               836      131          1205      116          1490
# ...             ...      ...           ...      ...           ...
# 9352           1101      472           539      190          1374
# 9353           1027      353           604      179          1264
# 9354           1063      293           603      175          1241
# 9355            961      235           702      156          1041
# 9356           1047      265           654      168          1129
#
#       PT08.S5(O3) Temperature Relative Humidity Absolute Humidity
# 0            1268        13,6              48,9             7,578
# 1             972        13,3              47,7             7,255
# 2            1074        11,9              54,0             7,502
# 3            1203        11,0              60,0             7,867
# 4            1110        11,2              59,6             7,888
# ...           ...         ...               ...               ...
# 9352         1729        21,9              29,3             7,568
# 9353         1269        24,3              23,7             7,119
# 9354         1092        26,9              18,3             6,406
# 9355          770        28,3              13,5             5,139
# 9356          816        28,5              13,1             5,028
#
# [9357 rows x 15 columns]

# %%
df['CO(GT)'] = df['CO(GT)'].str.replace(',', '.').astype(float)
df['C6H6(GT)'] = df['C6H6(GT)'].str.replace(',', '.').astype(float)
df['Temperature'] = df['Temperature'].str.replace(',', '.').astype(float)
df['Relative Humidity'] = df['Relative Humidity'].str.replace(',', '.').astype(float)
df['Absolute Humidity'] = df['Absolute Humidity'].str.replace(',', '.').astype(float)
df
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0     10/03/2004  18.00.00     2.6         1360       150      11.9
# 1     10/03/2004  19.00.00     2.0         1292       112       9.4
# 2     10/03/2004  20.00.00     2.2         1402        88       9.0
# 3     10/03/2004  21.00.00     2.2         1376        80       9.2
# 4     10/03/2004  22.00.00     1.6         1272        51       6.5
# ...          ...       ...     ...          ...       ...       ...
# 9352  04/04/2005  10.00.00     3.1         1314      -200      13.5
# 9353  04/04/2005  11.00.00     2.4         1163      -200      11.4
# 9354  04/04/2005  12.00.00     2.4         1142      -200      12.4
# 9355  04/04/2005  13.00.00     2.1         1003      -200       9.5
# 9356  04/04/2005  14.00.00     2.2         1071      -200      11.9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0              1046      166          1056      113          1692
# 1               955      103          1174       92          1559
# 2               939      131          1140      114          1555
# 3               948      172          1092      122          1584
# 4               836      131          1205      116          1490
# ...             ...      ...           ...      ...           ...
# 9352           1101      472           539      190          1374
# 9353           1027      353           604      179          1264
# 9354           1063      293           603      175          1241
# 9355            961      235           702      156          1041
# 9356           1047      265           654      168          1129
#
#       PT08.S5(O3)  Temperature  Relative Humidity  Absolute Humidity
# 0            1268         13.6               48.9              7.578
# 1             972         13.3               47.7              7.255
# 2            1074         11.9               54.0              7.502
# 3            1203         11.0               60.0              7.867
# 4            1110         11.2               59.6              7.888
# ...           ...          ...                ...                ...
# 9352         1729         21.9               29.3              7.568
# 9353         1269         24.3               23.7              7.119
# 9354         1092         26.9               18.3              6.406
# 9355          770         28.3               13.5              5.139
# 9356          816         28.5               13.1              5.028
#
# [9357 rows x 15 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9357 entries, 0 to 9356
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               9357 non-null   object
#  1   Time               9357 non-null   object
#  2   CO(GT)             9357 non-null   float64
#  3   PT08.S1(CO)        9357 non-null   int64
#  4   NMHC(GT)           9357 non-null   int64
#  5   C6H6(GT)           9357 non-null   float64
#  6   PT08.S2(NMHC)      9357 non-null   int64
#  7   NOx(GT)            9357 non-null   int64
#  8   PT08.S3(NOx)       9357 non-null   int64
#  9   NO2(GT)            9357 non-null   int64
#  10  PT08.S4(NO2)       9357 non-null   int64
#  11  PT08.S5(O3)        9357 non-null   int64
#  12  Temperature        9357 non-null   float64
#  13  Relative Humidity  9357 non-null   float64
#  14  Absolute Humidity  9357 non-null   float64
# dtypes: float64(5), int64(8), object(2)
# memory usage: 1.1+ MB

# %%
df.head()
# Out:
#          Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0  10/03/2004  18.00.00     2.6         1360       150      11.9
# 1  10/03/2004  19.00.00     2.0         1292       112       9.4
# 2  10/03/2004  20.00.00     2.2         1402        88       9.0
# 3  10/03/2004  21.00.00     2.2         1376        80       9.2
# 4  10/03/2004  22.00.00     1.6         1272        51       6.5
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0           1046      166          1056      113          1692         1268
# 1            955      103          1174       92          1559          972
# 2            939      131          1140      114          1555         1074
# 3            948      172          1092      122          1584         1203
# 4            836      131          1205      116          1490         1110
#
#    Temperature  Relative Humidity  Absolute Humidity
# 0         13.6               48.9              7.578
# 1         13.3               47.7              7.255
# 2         11.9               54.0              7.502
# 3         11.0               60.0              7.867
# 4         11.2               59.6              7.888

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Date, Time, CO(GT), PT08.S1(CO), NMHC(GT), C6H6(GT), PT08.S2(NMHC), NOx(GT), PT08.S3(NOx), NO2(GT), PT08.S4(NO2), PT08.S5(O3), Temperature, Relative Humidity, Absolute Humidity]
# Index: []

# %%
df=df.drop_duplicates()

# %%
df.isna().sum()
# Out:
# Date                 0
# Time                 0
# CO(GT)               0
# PT08.S1(CO)          0
# NMHC(GT)             0
# C6H6(GT)             0
# PT08.S2(NMHC)        0
# NOx(GT)              0
# PT08.S3(NOx)         0
# NO2(GT)              0
# PT08.S4(NO2)         0
# PT08.S5(O3)          0
# Temperature          0
# Relative Humidity    0
# Absolute Humidity    0
# dtype: int64

# %%
df['Absolute Humidity'] = df['Absolute Humidity'].multiply(100)
df
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0     10/03/2004  18.00.00     2.6         1360       150      11.9
# 1     10/03/2004  19.00.00     2.0         1292       112       9.4
# 2     10/03/2004  20.00.00     2.2         1402        88       9.0
# 3     10/03/2004  21.00.00     2.2         1376        80       9.2
# 4     10/03/2004  22.00.00     1.6         1272        51       6.5
# ...          ...       ...     ...          ...       ...       ...
# 9352  04/04/2005  10.00.00     3.1         1314      -200      13.5
# 9353  04/04/2005  11.00.00     2.4         1163      -200      11.4
# 9354  04/04/2005  12.00.00     2.4         1142      -200      12.4
# 9355  04/04/2005  13.00.00     2.1         1003      -200       9.5
# 9356  04/04/2005  14.00.00     2.2         1071      -200      11.9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0              1046      166          1056      113          1692
# 1               955      103          1174       92          1559
# 2               939      131          1140      114          1555
# 3               948      172          1092      122          1584
# 4               836      131          1205      116          1490
# ...             ...      ...           ...      ...           ...
# 9352           1101      472           539      190          1374
# 9353           1027      353           604      179          1264
# 9354           1063      293           603      175          1241
# 9355            961      235           702      156          1041
# 9356           1047      265           654      168          1129
#
#       PT08.S5(O3)  Temperature  Relative Humidity  Absolute Humidity
# 0            1268         13.6               48.9              757.8
# 1             972         13.3               47.7              725.5
# 2            1074         11.9               54.0              750.2
# 3            1203         11.0               60.0              786.7
# 4            1110         11.2               59.6              788.8
# ...           ...          ...                ...                ...
# 9352         1729         21.9               29.3              756.8
# 9353         1269         24.3               23.7              711.9
# 9354         1092         26.9               18.3              640.6
# 9355          770         28.3               13.5              513.9
# 9356          816         28.5               13.1              502.8
#
# [9357 rows x 15 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
def remove_outliers(column):
    Q1 = column.quantile(0.25)
    Q3 = column.quantile(0.75)
    IQR = Q3 - Q1
    threshold = 1.5 * IQR
    outlier_mask = (column < Q1 - threshold) | (column > Q3 + threshold)
    return column[~outlier_mask]

# %%
df.columns
# Out:
# Index(['Date', 'Time', 'CO(GT)', 'PT08.S1(CO)', 'NMHC(GT)', 'C6H6(GT)',
#        'PT08.S2(NMHC)', 'NOx(GT)', 'PT08.S3(NOx)', 'NO2(GT)', 'PT08.S4(NO2)',
#        'PT08.S5(O3)', 'Temperature', 'Relative Humidity', 'Absolute Humidity'],
#       dtype='object')

# %%
# Remove outliers for each column using a loop
col_name = ['Temperature','Relative Humidity','Absolute Humidity','PT08.S4(NO2)','PT08.S5(O3)','C6H6(GT)',
       'PT08.S2(NMHC)','PT08.S1(CO)']
for col in col_name:
    df[col] = remove_outliers(df[col])

# %%
df['Year'] = pd.to_datetime(df['Date'], dayfirst=True).dt.year
df['Month'] = pd.to_datetime(df['Date'], dayfirst=True).dt.month

# Check the DataFrame
print(df)
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0     10/03/2004  18.00.00     2.6       1360.0       150      11.9
# 1     10/03/2004  19.00.00     2.0       1292.0       112       9.4
# 2     10/03/2004  20.00.00     2.2       1402.0        88       9.0
# 3     10/03/2004  21.00.00     2.2       1376.0        80       9.2
# 4     10/03/2004  22.00.00     1.6       1272.0        51       6.5
# ...          ...       ...     ...          ...       ...       ...
# 9352  04/04/2005  10.00.00     3.1       1314.0      -200      13.5
# 9353  04/04/2005  11.00.00     2.4       1163.0      -200      11.4
# 9354  04/04/2005  12.00.00     2.4       1142.0      -200      12.4
# 9355  04/04/2005  13.00.00     2.1       1003.0      -200       9.5
# 9356  04/04/2005  14.00.00     2.2       1071.0      -200      11.9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0      166          1056      113        1692.0
# 1             955.0      103          1174       92        1559.0
# 2             939.0      131          1140      114        1555.0
# 3             948.0      172          1092      122        1584.0
# 4             836.0      131          1205      116        1490.0
# ...             ...      ...           ...      ...           ...
# 9352         1101.0      472           539      190        1374.0
# 9353         1027.0      353           604      179        1264.0
# 9354         1063.0      293           603      175        1241.0
# 9355          961.0      235           702      156        1041.0
# 9356         1047.0      265           654      168        1129.0
#
#       PT08.S5(O3)  Temperature  Relative Humidity  Absolute Humidity  Year  \
# 0          1268.0         13.6               48.9              757.8  2004
# 1           972.0         13.3               47.7              725.5  2004
# 2          1074.0         11.9               54.0              750.2  2004
# 3          1203.0         11.0               60.0              786.7  2004
# 4          1110.0         11.2               59.6              788.8  2004
# ...           ...          ...                ...                ...   ...
# 9352       1729.0         21.9               29.3              756.8  2005
# 9353       1269.0         24.3               23.7              711.9  2005
# 9354       1092.0         26.9               18.3              640.6  2005
# 9355        770.0         28.3               13.5              513.9  2005
# 9356        816.0         28.5               13.1              502.8  2005
#
#       Month
# 0         3
# 1         3
# 2         3
# 3         3
# 4         3
# ...     ...
# 9352      4
# 9353      4
# 9354      4
# 9355      4
# 9356      4
#
# [9357 rows x 17 columns]

# %%
df['yearr']= df.Year.astype(str)
df['month']= df.Month.astype(str)

# %%
numeric_df = df.select_dtypes(include=[float, int])
plt.figure(figsize=(12, 6))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
df.columns
# Out:
# Index(['Date', 'Time', 'CO(GT)', 'PT08.S1(CO)', 'NMHC(GT)', 'C6H6(GT)',
#        'PT08.S2(NMHC)', 'NOx(GT)', 'PT08.S3(NOx)', 'NO2(GT)', 'PT08.S4(NO2)',
#        'PT08.S5(O3)', 'Temperature', 'Relative Humidity', 'Absolute Humidity',
#        'Year', 'Month', 'yearr', 'month'],
#       dtype='object')

# %% [markdown]
# ## LinePlot

# %%
sns.lineplot(df,x="Year",y='Absolute Humidity')
# Out:
# <Axes: xlabel='Year', ylabel='Absolute Humidity'>

# %%
sns.lineplot(df,x="month",y='Absolute Humidity')
# Out:
# <Axes: xlabel='month', ylabel='Absolute Humidity'>

# %%
sns.lineplot(df,x="Year",y='Temperature')
# Out:
# <Axes: xlabel='Year', ylabel='Temperature'>

# %%
sns.lineplot(df,x="month",y='Temperature',)
# Out:
# <Axes: xlabel='month', ylabel='Temperature'>

# %%
sns.lineplot(df,x="month",y='CO(GT)',)
# Out:
# <Axes: xlabel='month', ylabel='CO(GT)'>

# %%
sns.lineplot(df,x="Year",y='NO2(GT)')
# Out:
# <Axes: xlabel='Year', ylabel='NO2(GT)'>

# %%
sns.lineplot(df,x="month",y='NO2(GT)')
# Out:
# <Axes: xlabel='month', ylabel='NO2(GT)'>

# %% [markdown]
# ## Barplot

# %%
sns.barplot(df,x=df.Year,y=df.Temperature)
# Out:
# <Axes: xlabel='Year', ylabel='Temperature'>

# %%
sns.barplot(df,x=df.month,y=df['CO(GT)'])
# Out:
# <Axes: xlabel='month', ylabel='CO(GT)'>

# %%
sns.barplot(df,x=df.Year,y='Absolute Humidity')
# Out:
# <Axes: xlabel='Year', ylabel='Absolute Humidity'>

# %%
sns.barplot(df,x=df.month,y='PT08.S1(CO)')
# Out:
# <Axes: xlabel='month', ylabel='PT08.S1(CO)'>

# %% [markdown]
# ## Scatter Plot

# %%
sns.scatterplot(df,x='PT08.S1(CO)',y='PT08.S5(O3)', hue='yearr')
# Out:
# <Axes: xlabel='PT08.S1(CO)', ylabel='PT08.S5(O3)'>

# %%
df.columns
# Out:
# Index(['Date', 'Time', 'CO(GT)', 'PT08.S1(CO)', 'NMHC(GT)', 'C6H6(GT)',
#        'PT08.S2(NMHC)', 'NOx(GT)', 'PT08.S3(NOx)', 'NO2(GT)', 'PT08.S4(NO2)',
#        'PT08.S5(O3)', 'Temperature', 'Relative Humidity', 'Absolute Humidity',
#        'Year', 'Month', 'yearr', 'month'],
#       dtype='object')

# %%
sns.scatterplot(df,x='NO2(GT)',y='NOx(GT)', hue='month')
# Out:
# <Axes: xlabel='NO2(GT)', ylabel='NOx(GT)'>

# %%
sns.scatterplot(df,y='PT08.S2(NMHC)',x='PT08.S1(CO)', hue='yearr')
# Out:
# <Axes: xlabel='PT08.S1(CO)', ylabel='PT08.S2(NMHC)'>

# %%
sns.scatterplot(df,y='PT08.S2(NMHC)',x='PT08.S1(CO)', hue='month')
# Out:
# <Axes: xlabel='PT08.S1(CO)', ylabel='PT08.S2(NMHC)'>
